# %%
import pandas as pd

# %%
path='our_world_in_data.xlsx'

# %%
df=pd.read_excel(path)

# %%
df
# Out:
#      iso_code continent     location last_updated_date  total_cases  \
# 0         AFG      Asia  Afghanistan        2021-09-14     154180.0
# 1    OWID_AFR       NaN       Africa        2021-09-14    8082453.0
# 2         ALB    Europe      Albania        2021-09-14     158431.0
# 3         DZA    Africa      Algeria        2021-09-14     200528.0
# 4         AND    Europe      Andorra        2021-09-14      15099.0
# ..        ...       ...          ...               ...          ...
# 217       VNM      Asia      Vietnam        2021-09-14     635055.0
# 218  OWID_WRL       NaN        World        2021-09-14  225805938.0
# 219       YEM      Asia        Yemen        2021-09-14       8502.0
# 220       ZMB    Africa       Zambia        2021-09-14     208049.0
# 221       ZWE    Africa     Zimbabwe        2021-09-14     126817.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0         86.0              79.143        7171.0         2.0
# ...

# %%
df.head(5)
# Out:
#    iso_code continent     location last_updated_date  total_cases  new_cases  \
# 0       AFG      Asia  Afghanistan        2021-09-14     154180.0       86.0
# 1  OWID_AFR       NaN       Africa        2021-09-14    8082453.0    25179.0
# 2       ALB    Europe      Albania        2021-09-14     158431.0      995.0
# 3       DZA    Africa      Algeria        2021-09-14     200528.0      227.0
# 4       AND    Europe      Andorra        2021-09-14      15099.0        3.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0              79.143        7171.0         2.0                3.857  ...
# 1           18769.571      203924.0       608.0              500.571  ...
# 2             884.571        2553.0         5.0                4.286  ...
# 3             269.000        5614.0        18.0               20.429  ...
# 4               4.143         130.0         0.0                0.000  ...
#
# ...

# %%
df.sort_values('location',ascending=True)
# Out:
#      iso_code continent     location last_updated_date  total_cases  \
# 0         AFG      Asia  Afghanistan        2021-09-14     154180.0
# 1    OWID_AFR       NaN       Africa        2021-09-14    8082453.0
# 2         ALB    Europe      Albania        2021-09-14     158431.0
# 3         DZA    Africa      Algeria        2021-09-14     200528.0
# 4         AND    Europe      Andorra        2021-09-14      15099.0
# ..        ...       ...          ...               ...          ...
# 217       VNM      Asia      Vietnam        2021-09-14     635055.0
# 218  OWID_WRL       NaN        World        2021-09-14  225805938.0
# 219       YEM      Asia        Yemen        2021-09-14       8502.0
# 220       ZMB    Africa       Zambia        2021-09-14     208049.0
# 221       ZWE    Africa     Zimbabwe        2021-09-14     126817.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0         86.0              79.143        7171.0         2.0
# ...

# %%
df.loc[df['location']=='India']
# Out:
#    iso_code continent location last_updated_date  total_cases  new_cases  \
# 93      IND      Asia    India        2021-09-14   33316755.0    27176.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 93           31433.857      443497.0       284.0                298.0  ...
#
#     extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 93             21.2                 282.28                10.39
#
#     female_smokers  male_smokers  handwashing_facilities  \
# 93             1.9          20.6                   59.55
#
#     hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 93                        0.53            69.66                    0.645
#
#     excess_mortality
# 93               NaN
#
# [1 rows x 62 columns]

# %% [markdown]
# in the line 15 we use above code to search particular value in the big data frame in row or column value to search particular data or all data for analysis

# %%
df['location'] = df['location'].replace(['India'],'somu')

# %%
df.loc[df['location']=='somu']
# Out:
#    iso_code continent location last_updated_date  total_cases  new_cases  \
# 93      IND      Asia     somu        2021-09-14   33316755.0    27176.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 93           31433.857      443497.0       284.0                298.0  ...
#
#     extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 93             21.2                 282.28                10.39
#
#     female_smokers  male_smokers  handwashing_facilities  \
# 93             1.9          20.6                   59.55
#
#     hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 93                        0.53            69.66                    0.645
#
#     excess_mortality
# 93               NaN
#
# [1 rows x 62 columns]

# %%
df['location'] = df['location'].replace(['somu'],'India')

# %%
df.loc[df['location']=='India']
# Out:
#    iso_code continent location last_updated_date  total_cases  new_cases  \
# 93      IND      Asia    India        2021-09-14   33316755.0    27176.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 93           31433.857      443497.0       284.0                298.0  ...
#
#     extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 93             21.2                 282.28                10.39
#
#     female_smokers  male_smokers  handwashing_facilities  \
# 93             1.9          20.6                   59.55
#
#     hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 93                        0.53            69.66                    0.645
#
#     excess_mortality
# 93               NaN
#
# [1 rows x 62 columns]

# %% [markdown]
# for editing or replaceing any value or name in the data frame

# %%
df
# Out:
#      iso_code continent     location last_updated_date  total_cases  \
# 0         AFG      Asia  Afghanistan        2021-09-14     154180.0
# 1    OWID_AFR       NaN       Africa        2021-09-14    8082453.0
# 2         ALB    Europe      Albania        2021-09-14     158431.0
# 3         DZA    Africa      Algeria        2021-09-14     200528.0
# 4         AND    Europe      Andorra        2021-09-14      15099.0
# ..        ...       ...          ...               ...          ...
# 217       VNM      Asia      Vietnam        2021-09-14     635055.0
# 218  OWID_WRL       NaN        World        2021-09-14  225805938.0
# 219       YEM      Asia        Yemen        2021-09-14       8502.0
# 220       ZMB    Africa       Zambia        2021-09-14     208049.0
# 221       ZWE    Africa     Zimbabwe        2021-09-14     126817.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0         86.0              79.143        7171.0         2.0
# ...

# %%
df.max()
# Out:
# C:\Users\USER1\AppData\Local\Programs\Python\Python39\Scripts/ipykernel_8640/1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# iso_code                                          ZWE
# location                                     Zimbabwe
# last_updated_date                          2021-09-14
# total_cases                               225805938.0
# new_cases                                    535799.0
# new_cases_smoothed                         550586.429
# total_deaths                                4648435.0
# new_deaths                                     8816.0
# new_deaths_smoothed                          8767.714
# total_cases_per_million                    208199.373
# new_cases_per_million                        4904.949
# new_cases_smoothed_per_million               1305.769
# ...
