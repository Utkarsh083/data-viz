# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path="Downloads/gdp-per-capita-maddison-2020.csv"

# %%
world=pd.read_csv(path)

# %%
world
# Out:
#             Entity Code  Year  GDP per capita 145446-annotations
# 0      Afghanistan  AFG  1950         1156.00                NaN
# 1      Afghanistan  AFG  1951         1170.00                NaN
# 2      Afghanistan  AFG  1952         1189.00                NaN
# 3      Afghanistan  AFG  1953         1240.00                NaN
# 4      Afghanistan  AFG  1954         1245.00                NaN
# ...            ...  ...   ...             ...                ...
# 19873     Zimbabwe  ZWE  2014         1594.00                NaN
# 19874     Zimbabwe  ZWE  2015         1560.00                NaN
# 19875     Zimbabwe  ZWE  2016         1534.00                NaN
# 19876     Zimbabwe  ZWE  2017         1582.37                NaN
# 19877     Zimbabwe  ZWE  2018         1611.41                NaN
#
# [19878 rows x 5 columns]

# %%
india=world[world["Entity"]=="India"]

# %%
india
# Out:
#      Entity Code  Year  GDP per capita 145446-annotations
# 7178  India  IND  1600         1264.00                NaN
# 7179  India  IND  1650         1189.00                NaN
# 7180  India  IND  1700         1162.00                NaN
# 7181  India  IND  1750         1068.00                NaN
# 7182  India  IND  1801         1033.00                NaN
# ...     ...  ...   ...             ...                ...
# 7321  India  IND  2014         5458.00                NaN
# 7322  India  IND  2015         5794.00                NaN
# 7323  India  IND  2016         6125.00                NaN
# 7324  India  IND  2017         6449.11                NaN
# 7325  India  IND  2018         6806.50                NaN
#
# [148 rows x 5 columns]

# %%
us=world[world["Entity"]=="United States"]

# %%
us
# Out:
#               Entity Code  Year  GDP per capita 145446-annotations
# 18933  United States  USA  1650          897.00                NaN
# 18934  United States  USA  1720         1768.99                NaN
# 18935  United States  USA  1775         2419.00                NaN
# 18936  United States  USA  1800         2545.49                NaN
# 18937  United States  USA  1801         2591.77                NaN
# ...              ...  ...   ...             ...                ...
# 19150  United States  USA  2014        51664.00                NaN
# 19151  United States  USA  2015        52591.00                NaN
# 19152  United States  USA  2016        53015.00                NaN
# 19153  United States  USA  2017        54007.77                NaN
# 19154  United States  USA  2018        55334.74                NaN
#
# [222 rows x 5 columns]

# %%
china=world[world["Entity"]=="China"]

# %%
china
# Out:
#      Entity Code  Year  GDP per capita 145446-annotations
# 2750  China  CHN  1000         1225.11                NaN
# 2751  China  CHN  1090         1221.71                NaN
# 2752  China  CHN  1120         1180.96                NaN
# 2753  China  CHN  1400         1404.25                NaN
# 2754  China  CHN  1410         1414.00                NaN
# ...     ...  ...   ...             ...                ...
# 2877  China  CHN  2014        11944.00                NaN
# 2878  China  CHN  2015        12244.00                NaN
# 2879  China  CHN  2016        12569.00                NaN
# 2880  China  CHN  2017        12733.93                NaN
# 2881  China  CHN  2018        13101.71                NaN
#
# [132 rows x 5 columns]

# %%
india.plot(x="Year",y="GDP per capita",kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
us.plot(x="Year",y="GDP per capita",kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
china.plot(x="Year",y="GDP per capita",kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
china1=china.tail(50)

# %%
china1.plot(x="Year",y="GDP per capita",kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
india1=india.tail(50)

# %%
india1.plot(x="Year",y="GDP per capita",kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
usa=us.tail(50)

# %%
usa.plot(x="Year",y="GDP per capita",kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
india1.sort_values("GDP per capita",ascending=False)
# Out:
#      Entity Code  Year  GDP per capita 145446-annotations
# 7325  India  IND  2018         6806.50                NaN
# 7324  India  IND  2017         6449.11                NaN
# 7323  India  IND  2016         6125.00                NaN
# 7322  India  IND  2015         5794.00                NaN
# 7321  India  IND  2014         5458.00                NaN
# 7320  India  IND  2013         5172.00                NaN
# 7319  India  IND  2012         4932.00                NaN
# 7318  India  IND  2011         4768.00                NaN
# 7317  India  IND  2010         4525.75                NaN
# 7316  India  IND  2009         4270.71                NaN
# 7315  India  IND  2008         4030.65                NaN
# 7314  India  IND  2007         3870.70                NaN
# 7313  India  IND  2006         3629.41                NaN
# 7312  India  IND  2005         3396.65                NaN
# 7311  India  IND  2004         3212.51                NaN
# ...

# %%
india["Region"]="Asia"
# Out:
# C:\Users\USER1\AppData\Local\Programs\Python\Python39\Scripts/ipykernel_1640/3267954419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india["Region"]="Asia"

# %%
india
# Out:
#      Entity Code  Year  GDP per capita 145446-annotations Region
# 7178  India  IND  1600         1264.00                NaN   Asia
# 7179  India  IND  1650         1189.00                NaN   Asia
# 7180  India  IND  1700         1162.00                NaN   Asia
# 7181  India  IND  1750         1068.00                NaN   Asia
# 7182  India  IND  1801         1033.00                NaN   Asia
# ...     ...  ...   ...             ...                ...    ...
# 7321  India  IND  2014         5458.00                NaN   Asia
# 7322  India  IND  2015         5794.00                NaN   Asia
# 7323  India  IND  2016         6125.00                NaN   Asia
# 7324  India  IND  2017         6449.11                NaN   Asia
# 7325  India  IND  2018         6806.50                NaN   Asia
#
# [148 rows x 6 columns]

# %%
del india["145446-annotations"]

# %%
india
# Out:
#      Entity Code  Year  GDP per capita Region
# 7178  India  IND  1600         1264.00   Asia
# 7179  India  IND  1650         1189.00   Asia
# 7180  India  IND  1700         1162.00   Asia
# 7181  India  IND  1750         1068.00   Asia
# 7182  India  IND  1801         1033.00   Asia
# ...     ...  ...   ...             ...    ...
# 7321  India  IND  2014         5458.00   Asia
# 7322  India  IND  2015         5794.00   Asia
# 7323  India  IND  2016         6125.00   Asia
# 7324  India  IND  2017         6449.11   Asia
# 7325  India  IND  2018         6806.50   Asia
#
# [148 rows x 5 columns]

# %%
india["Index"]=""
# Out:
# C:\Users\USER1\AppData\Local\Programs\Python\Python39\Scripts/ipykernel_1640/3733530677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india["Index"]=""

# %%
del india["Index"]

# %%
india
# Out:
#      Entity Code  Year  GDP per capita Region
# 7178  India  IND  1600         1264.00   Asia
# 7179  India  IND  1650         1189.00   Asia
# 7180  India  IND  1700         1162.00   Asia
# 7181  India  IND  1750         1068.00   Asia
# 7182  India  IND  1801         1033.00   Asia
# ...     ...  ...   ...             ...    ...
# 7321  India  IND  2014         5458.00   Asia
# 7322  India  IND  2015         5794.00   Asia
# 7323  India  IND  2016         6125.00   Asia
# 7324  India  IND  2017         6449.11   Asia
# 7325  India  IND  2018         6806.50   Asia
#
# [148 rows x 5 columns]

# %%
for index,row in india.iterrows():
    if row["GDP per capita"]>3000.00:
        print("Entity",Entity,"GDP per capita",GDP per capita)
# Out:
#   File "C:\Users\USER1\AppData\Local\Programs\Python\Python39\Scripts/ipykernel_1640/3901375190.py", line 3
#     print("Entity",Entity,"GDP per capita",GDP per capita)
#                                                ^
# SyntaxError: invalid syntax

# %%
india.rename(columns={"GDP per capita":"gdp"},
          inplace=True)
# Out:
# c:\users\user1\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
india
# Out:
#      Entity Code  Year      gdp Region
# 7178  India  IND  1600  1264.00   Asia
# 7179  India  IND  1650  1189.00   Asia
# 7180  India  IND  1700  1162.00   Asia
# 7181  India  IND  1750  1068.00   Asia
# 7182  India  IND  1801  1033.00   Asia
# ...     ...  ...   ...      ...    ...
# 7321  India  IND  2014  5458.00   Asia
# 7322  India  IND  2015  5794.00   Asia
# 7323  India  IND  2016  6125.00   Asia
# 7324  India  IND  2017  6449.11   Asia
# 7325  India  IND  2018  6806.50   Asia
#
# [148 rows x 5 columns]

# %%
for index,row in india.iterrows():
    if row["gdp"]>3000.00:
        print(index,row["Entity"],row["gdp"],row["Year"])
# Out:
# 7310 India 3035.92 2003
# 7311 India 3212.51 2004
# 7312 India 3396.65 2005
# 7313 India 3629.41 2006
# 7314 India 3870.7 2007
# 7315 India 4030.65 2008
# 7316 India 4270.71 2009
# 7317 India 4525.75 2010
# 7318 India 4768.0 2011
# 7319 India 4932.0 2012
# 7320 India 5172.0 2013
# 7321 India 5458.0 2014
# 7322 India 5794.0 2015
# 7323 India 6125.0 2016
# 7324 India 6449.11 2017
# 7325 India 6806.5 2018
