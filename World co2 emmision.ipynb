# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path="annual-co-emissions-by-region.csv"

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#             Entity Code  Year  Annual CO2 emissions (zero filled)
# 0      Afghanistan  AFG  1750                                   0
# 1      Afghanistan  AFG  1751                                   0
# 2      Afghanistan  AFG  1752                                   0
# 3      Afghanistan  AFG  1753                                   0
# 4      Afghanistan  AFG  1754                                   0
# ...            ...  ...   ...                                 ...
# 64255     Zimbabwe  ZWE  2015                            12170460
# 64256     Zimbabwe  ZWE  2016                            10814761
# 64257     Zimbabwe  ZWE  2017                            10246841
# 64258     Zimbabwe  ZWE  2018                            11340575
# 64259     Zimbabwe  ZWE  2019                            10374287
#
# [64260 rows x 4 columns]

# %%
india= df[df['Entity']=="India"]

# %%
india
# Out:
#       Entity Code  Year  Annual CO2 emissions (zero filled)
# 26730  India  IND  1750                                   0
# 26731  India  IND  1751                                   0
# 26732  India  IND  1752                                   0
# 26733  India  IND  1753                                   0
# 26734  India  IND  1754                                   0
# ...      ...  ...   ...                                 ...
# 26995  India  IND  2015                          2253428782
# 26996  India  IND  2016                          2392359728
# 26997  India  IND  2017                          2456847641
# 26998  India  IND  2018                          2591323739
# 26999  India  IND  2019                          2616448820
#
# [270 rows x 4 columns]

# %%
indiatl=india.tail(30)

# %%
indiatl
# Out:
#       Entity Code  Year  Annual CO2 emissions (zero filled)
# 26970  India  IND  1990                           578687007
# 26971  India  IND  1991                           616105953
# 26972  India  IND  1992                           656222624
# 26973  India  IND  1993                           678115765
# 26974  India  IND  1994                           717127462
# 26975  India  IND  1995                           762337913
# 26976  India  IND  1996                           826151223
# 26977  India  IND  1997                           859929300
# 26978  India  IND  1998                           877939472
# 26979  India  IND  1999                           951671195
# 26980  India  IND  2000                           978426962
# 26981  India  IND  2001                           992529169
# 26982  India  IND  2002                          1022848986
# 26983  India  IND  2003                          1059415912
# 26984  India  IND  2004                          1125263670
# ...

# %%
indiatl.plot(x="Year", y="Annual CO2 emissions (zero filled)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world= df[df['Entity']=="World"]

# %%
world
# Out:
#       Entity      Code  Year  Annual CO2 emissions (zero filled)
# 63180  World  OWID_WRL  1750                             9350528
# 63181  World  OWID_WRL  1751                             9350528
# 63182  World  OWID_WRL  1752                             9354192
# 63183  World  OWID_WRL  1753                             9354192
# 63184  World  OWID_WRL  1754                             9357856
# ...      ...       ...   ...                                 ...
# 63445  World  OWID_WRL  2015                         35209446562
# 63446  World  OWID_WRL  2016                         35220412420
# 63447  World  OWID_WRL  2017                         35696348890
# 63448  World  OWID_WRL  2018                         36419711706
# 63449  World  OWID_WRL  2019                         36441387575
#
# [270 rows x 4 columns]

# %%
worldtl=world.tail(30)

# %%
worldtl
# Out:
#       Entity      Code  Year  Annual CO2 emissions (zero filled)
# 63420  World  OWID_WRL  1990                         22697611920
# 63421  World  OWID_WRL  1991                         23169529331
# 63422  World  OWID_WRL  1992                         22444951326
# 63423  World  OWID_WRL  1993                         22682603213
# 63424  World  OWID_WRL  1994                         22843787723
# 63425  World  OWID_WRL  1995                         23332159074
# 63426  World  OWID_WRL  1996                         24050843644
# 63427  World  OWID_WRL  1997                         24191148150
# 63428  World  OWID_WRL  1998                         24112118810
# 63429  World  OWID_WRL  1999                         24431050755
# 63430  World  OWID_WRL  2000                         25119042307
# 63431  World  OWID_WRL  2001                         25332202521
# 63432  World  OWID_WRL  2002                         25911186282
# ...

# %%
worldtl.plot(x="Year", y="Annual CO2 emissions (zero filled)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
china= df[df['Entity']=="China"]

# %%
china
# Out:
#       Entity Code  Year  Annual CO2 emissions (zero filled)
# 11880  China  CHN  1750                                   0
# 11881  China  CHN  1751                                   0
# 11882  China  CHN  1752                                   0
# 11883  China  CHN  1753                                   0
# 11884  China  CHN  1754                                   0
# ...      ...  ...   ...                                 ...
# 12145  China  CHN  2015                          9683200711
# 12146  China  CHN  2016                          9552516545
# 12147  China  CHN  2017                          9750725978
# 12148  China  CHN  2018                          9956568523
# 12149  China  CHN  2019                         10174681103
#
# [270 rows x 4 columns]

# %%
chinatl=china.tail(30)

# %%
chinatl.plot(x="Year", y="Annual CO2 emissions (zero filled)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
US= df[df['Entity']=="United States"]

# %%
US
# Out:
#               Entity Code  Year  Annual CO2 emissions (zero filled)
# 61290  United States  USA  1750                                   0
# 61291  United States  USA  1751                                   0
# 61292  United States  USA  1752                                   0
# 61293  United States  USA  1753                                   0
# 61294  United States  USA  1754                                   0
# ...              ...  ...   ...                                 ...
# 61555  United States  USA  2015                          5412432194
# 61556  United States  USA  2016                          5292267561
# 61557  United States  USA  2017                          5253606130
# 61558  United States  USA  2018                          5424881502
# 61559  United States  USA  2019                          5284696657
#
# [270 rows x 4 columns]

# %%
ustl=US.tail(30)

# %%
ustl
# Out:
#               Entity Code  Year  Annual CO2 emissions (zero filled)
# 61530  United States  USA  1990                          5128300617
# 61531  United States  USA  1991                          5078889576
# 61532  United States  USA  1992                          5182706720
# 61533  United States  USA  1993                          5283437595
# 61534  United States  USA  1994                          5377032708
# 61535  United States  USA  1995                          5438905704
# 61536  United States  USA  1996                          5626911901
# 61537  United States  USA  1997                          5703706968
# 61538  United States  USA  1998                          5751051980
# 61539  United States  USA  1999                          5830297636
# 61540  United States  USA  2000                          5998070434
# 61541  United States  USA  2001                          5900436596
# 61542  United States  USA  2002                          5942652335
# ...

# %%
ustl.plot(x="Year", y="Annual CO2 emissions (zero filled)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
ustl.rename(columns = {"Annual CO2 emissions (zero filled)":"co2_emmision"}, inplace = True)
# Out:
# C:\Users\USER1\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
ustl
# Out:
#               Entity Code  Year  co2_emmision
# 61530  United States  USA  1990    5128300617
# 61531  United States  USA  1991    5078889576
# 61532  United States  USA  1992    5182706720
# 61533  United States  USA  1993    5283437595
# 61534  United States  USA  1994    5377032708
# 61535  United States  USA  1995    5438905704
# 61536  United States  USA  1996    5626911901
# 61537  United States  USA  1997    5703706968
# 61538  United States  USA  1998    5751051980
# 61539  United States  USA  1999    5830297636
# 61540  United States  USA  2000    5998070434
# 61541  United States  USA  2001    5900436596
# 61542  United States  USA  2002    5942652335
# 61543  United States  USA  2003    5991959633
# 61544  United States  USA  2004    6107618246
# 61545  United States  USA  2005    6131892976
# 61546  United States  USA  2006    6051051022
# 61547  United States  USA  2007    6128429640
# 61548  United States  USA  2008    5930539643
# ...

# %%
ustl.sort_values('co2_emmision',ascending=False)
# Out:
#               Entity Code  Year  co2_emmision
# 61545  United States  USA  2005    6131892976
# 61547  United States  USA  2007    6128429640
# 61544  United States  USA  2004    6107618246
# 61546  United States  USA  2006    6051051022
# 61540  United States  USA  2000    5998070434
# 61543  United States  USA  2003    5991959633
# 61542  United States  USA  2002    5942652335
# 61548  United States  USA  2008    5930539643
# 61541  United States  USA  2001    5900436596
# 61539  United States  USA  1999    5830297636
# 61538  United States  USA  1998    5751051980
# 61537  United States  USA  1997    5703706968
# 61550  United States  USA  2010    5698055779
# 61536  United States  USA  1996    5626911901
# 61551  United States  USA  2011    5565294401
# 61554  United States  USA  2014    5561719216
# 61553  United States  USA  2013    5514029294
# 61549  United States  USA  2009    5491035727
# 61535  United States  USA  1995    5438905704
# ...

# %%
indiatl.rename(columns = {"Annual CO2 emissions (zero filled)":"co2_emmision"}, inplace = True)
# Out:
# C:\Users\USER1\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
indiatl.sort_values("co2_emmision",ascending=False)
# Out:
#       Entity Code  Year  co2_emmision
# 26999  India  IND  2019    2616448820
# 26998  India  IND  2018    2591323739
# 26997  India  IND  2017    2456847641
# 26996  India  IND  2016    2392359728
# 26995  India  IND  2015    2253428782
# 26994  India  IND  2014    2184432168
# 26993  India  IND  2013    2033412295
# 26992  India  IND  2012    1941312654
# 26991  India  IND  2011    1766065040
# 26990  India  IND  2010    1678478677
# 26989  India  IND  2009    1612514671
# 26988  India  IND  2008    1462573990
# 26987  India  IND  2007    1357915604
# 26986  India  IND  2006    1259522463
# 26985  India  IND  2005    1185760668
# 26984  India  IND  2004    1125263670
# 26983  India  IND  2003    1059415912
# 26982  India  IND  2002    1022848986
# 26981  India  IND  2001     992529169
# 26980  India  IND  2000     978426962
# 26979  India  IND  1999     951671195
# 26978  India  IND  1998     877939472
# 26977  India  IND  1997     859929300
# 26976  India  IND  1996     826151223
# ...

# %%
df
# Out:
#             Entity Code  Year  Annual CO2 emissions (zero filled)
# 0      Afghanistan  AFG  1750                                   0
# 1      Afghanistan  AFG  1751                                   0
# 2      Afghanistan  AFG  1752                                   0
# 3      Afghanistan  AFG  1753                                   0
# 4      Afghanistan  AFG  1754                                   0
# ...            ...  ...   ...                                 ...
# 64255     Zimbabwe  ZWE  2015                            12170460
# 64256     Zimbabwe  ZWE  2016                            10814761
# 64257     Zimbabwe  ZWE  2017                            10246841
# 64258     Zimbabwe  ZWE  2018                            11340575
# 64259     Zimbabwe  ZWE  2019                            10374287
#
# [64260 rows x 4 columns]
