# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path="Downloads/children-born-per-woman.csv"

# %%
df=pd.read_csv(path)
df
# Out:
#             Entity Code  Year  Fertility rate (Select Gapminder, v12) (2017)
# 0      Afghanistan  AFG  1950                                           7.57
# 1      Afghanistan  AFG  1951                                           7.56
# 2      Afghanistan  AFG  1952                                           7.55
# 3      Afghanistan  AFG  1953                                           7.54
# 4      Afghanistan  AFG  1954                                           7.53
# ...            ...  ...   ...                                            ...
# 21577     Zimbabwe  ZWE  2015                                           3.84
# 21578     Zimbabwe  ZWE  2016                                           3.76
# 21579     Zimbabwe  ZWE  2017                                           3.68
# 21580     Zimbabwe  ZWE  2018                                           3.61
# 21581     Zimbabwe  ZWE  2019                                           3.53
#
# [21582 rows x 4 columns]

# %% [markdown]
# # Fertility rate analysis of top Asian countries

# %%
#India
india=df[df["Entity"]=="India"]

# %%
india.plot(x="Year",y="Fertility rate (Select Gapminder, v12) (2017)",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.rename(columns = {'Fertility rate (Select Gapminder, v12) (2017)':'fertility rate'}, inplace = True)

# %%
df
# Out:
#             Entity Code  Year  fertility rate
# 0      Afghanistan  AFG  1950            7.57
# 1      Afghanistan  AFG  1951            7.56
# 2      Afghanistan  AFG  1952            7.55
# 3      Afghanistan  AFG  1953            7.54
# 4      Afghanistan  AFG  1954            7.53
# ...            ...  ...   ...             ...
# 21577     Zimbabwe  ZWE  2015            3.84
# 21578     Zimbabwe  ZWE  2016            3.76
# 21579     Zimbabwe  ZWE  2017            3.68
# 21580     Zimbabwe  ZWE  2018            3.61
# 21581     Zimbabwe  ZWE  2019            3.53
#
# [21582 rows x 4 columns]

# %%
#Pakistan
pak=df[df["Entity"]=="Pakistan"]

# %%
pak.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Bangladesh
bd=df[df["Entity"]=="Bangladesh"]
bd.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#China
china=df[df["Entity"]=="China"]
china.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#indonesia
indo=df[df["Entity"]=="Indonesia"]
indo.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# REPORT- There is declining trend in overall fertility ratio in Asian countries. There is no sign of peak in asian countries as the data provided but if we see the image in broader way then it is estimated that the peak by all Asian countries already attained in around mid 20th centuary and average fertility ratio declining trend started at around 1965 and since then there is steep downward trend shown in top economise of Asian countries.

# %% [markdown]
# # Fertility rate analysis of top European countries

# %%
#UK
uk=df[df["Entity"]=="United Kingdom"]
uk.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#France
fr=df[df["Entity"]=="France"]
fr.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Germany
ger=df[df["Entity"]=="Germany"]
ger.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Russia
rsa=df[df["Entity"]=="Russia"]
rsa.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Norway
nry=df[df["Entity"]=="Norway"]
nry.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Italy
italy=df[df["Entity"]=="Italy"]
italy.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Report- It is to be estimated that average fertility ratio of Europe, if we see the top economies that overall ratio is declined and touched the vally point and there is no sign of early rising trend in the fertility ratio still there is chance if there is late bounce back after the vally then we might see the stablility in the ratio for over the next 50 years if we apply more advance prediction models.

# %% [markdown]
# # Fertility ratio analysis for the American Sub-continent

# %%
#United States
US=df[df["Entity"]=="United States"]
US.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Brazil
brl=df[df["Entity"]=="Brazil"]
brl.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Mexico
mex=df[df["Entity"]=="Mexico"]
mex.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Colombia
col=df[df["Entity"]=="Colombia"]
col.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Argentina
arg=df[df["Entity"]=="Argentina"]
arg.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Peru
pr=df[df["Entity"]=="Peru"]
pr.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# REPORT- According to the above visuals and graphs, the countries in the american continents both north and south shows Declining trend since the mid 60's and 70's and still in most off the countries it is estimated that some countries are attaining the valley point. since the countries in both north and south shows dissimilar trend but still pictures shows overall fertility ratio declining.

# %% [markdown]
# # Fertility ratio in Oceania region

# %%
#Australia
aus=df[df["Entity"]=="Australia"]
aus.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#New_Zealand
nz=df[df["Entity"]=="Australia"]
nz.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# REPORT-The two main countries Australia and New Zealand shows the similar pattern. According to the data shown above the decline in the fertility ratio start during 1850's and attain the valley at somewhere around between 1930 and 1935.
# Then after the secondary peak during 60's there is further decline in the fertility rate across oceanic region and seems to be in stable line further after the 21st centuary. And if we follow the current trend line then the line should be stable in future if we apply more prediction models.

# %% [markdown]
# # Fertility rate analysis in African continent

# %%
#South_Africa
sa=df[df["Entity"]=="South Africa"]
sa.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Nigeria
ngr=df[df["Entity"]=="Nigeria"]
ngr.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Niger
nigr=df[df["Entity"]=="Niger"]
nigr.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Mali
ml=df[df["Entity"]=="Mali"]
ml.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#DRC
DRC=df[df["Entity"]=="Democratic Republic of Congo"]
DRC.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Botswana
bot=df[df["Entity"]=="Botswana"]
bot.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Zimbabwe
zm=df[df["Entity"]=="Zimbabwe"]
zm.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Namibia
nam=df[df["Entity"]=="Namibia"]
nam.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# REPORT- There are two trends shown in the African continent. If we check the north african countries there are very high fertility ratio and if we see the southern countries it shows the low fertility ratio, but still there is similarity between the northern and southern countries that the overall fertility ratio is declining and it seems to follow the same downward path further down in future.

# %% [markdown]
# # Fertility rate analysis and conclusion of the World

# %%
#World
wrld=df[df["Entity"]=="World"]
wrld.plot(x="Year",y="fertility rate",kind="line")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Conclusion- The over all fertility rate is in declining phase after the mid 20th centuary. And if we follow the current trend line it is estimated that it will further decline till 2040 in future.
